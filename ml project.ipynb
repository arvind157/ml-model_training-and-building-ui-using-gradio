# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\arv20\Desktop\5th sem\ML PROJECT\Customer Feedback.csv')
df.head()
# Out:
#                         Timestamp                Username              Name  \
# 0  2022/12/25 3:18:40 PM GMT+5:30      erchitra@gmail.com  Sibhinandhan.E.R
# 1  2022/12/25 3:20:19 PM GMT+5:30   rsujithgopi@gmail.com     R.Sujith Gopi
# 2  2022/12/25 3:23:21 PM GMT+5:30      paavi795@gmail.com          Pavithra
# 3  2022/12/25 3:24:08 PM GMT+5:30    pranovshan@gmail.com  U Pranov Shanker
# 4  2022/12/25 3:24:23 PM GMT+5:30  anjuvenu2005@gmail.com           Anjana
#
#      Stream On an average, how many hours a week do you spend on academics?  \
# 0   Science                                            13 - 20
# 1   Science                                            13 - 20
# 2  Commerce                                             5 - 12
# 3   Science                                            13 - 20
# 4   Science                                             5 - 12
#
#   Do timetables and deadlines stress you out ?  \
# 0                                        Maybe
# ...

# %%
df.rename(columns={
'On an average, how many hours a week do you spend on academics?':'academic time',
'Do timetables and deadlines stress you out ?':'timetables and deadlines',
'How willing are you to work on a particular task ? [with deadlines]':'task dedication',
'How willing are you to work on a particular task ? [without deadlines]':'task without deadlines',    
'Do you take up  any physical activity at regular intervals(at least 3 hours a week) ?':'physical activity',
'Choose your favourite sport you follow or play':'favorite sport',
'Do you actively and regularly participate in your favourite sport?':'sport participation',
'How often do you spend time with your friends and family?':'family time',
'Has poor sleep troubled you in the last month?':'poor sleep',
'What is your current level of fitness?':'fitness',
' What are some of the achievements that you are proud of?':'acheivements',
'How often have you felt the following? [Empty]':'empty feeling',
'How often have you felt the following? [Unable to concentrate in classes and other activities]':'loss of concentration',
'How often have you felt the following? [Either under eating or overeating]':'eating habits',
'How often have you felt the following? [Distressed]':'distressed',
'How often have you felt the following? [Little interest in talking to family and friends]':'losing interest in life',
'How often have you felt the following? [Irritable]':'irritatable',
'How many hours of free time do you have after school?':'free time', 
' Do your teachers encourage you to perform better after each test?':'encouragement',
'What motivates you to learn more?':'motivation',
'How would you evaluate the overall academic experience you had with this faculty in your institution?':'academic experience',
'How long you spend your time on social media on a daily basis? ':'social media',
'Do you feel that spending time on social media has been a reason for the deterioration in your academic performance?':'socail media on academics' ,
'Rate your performance in your academics':'performance',
'How satisfied are you with your life?':'satisfication'      
},inplace=True)

# %%
df.head(10)
# Out:
#                         Timestamp                              Username  \
# 0  2022/12/25 3:18:40 PM GMT+5:30                    erchitra@gmail.com
# 1  2022/12/25 3:20:19 PM GMT+5:30                 rsujithgopi@gmail.com
# 2  2022/12/25 3:23:21 PM GMT+5:30                    paavi795@gmail.com
# 3  2022/12/25 3:24:08 PM GMT+5:30                  pranovshan@gmail.com
# 4  2022/12/25 3:24:23 PM GMT+5:30                anjuvenu2005@gmail.com
# 5  2022/12/25 3:24:57 PM GMT+5:30  dhatchayinisathyanarayanan@gmail.com
# 6  2022/12/25 3:25:45 PM GMT+5:30                     vibab81@gmail.com
# 7  2022/12/25 3:26:28 PM GMT+5:30               advaithnirmal@gmail.com
# 8  2022/12/25 3:29:57 PM GMT+5:30              nikholaseyyy05@gmail.com
# 9  2022/12/25 3:30:03 PM GMT+5:30              dhruvitasmenon@gmail.com
#
#                 Name    Stream academic time timetables and deadlines  \
# 0   Sibhinandhan.E.R   Science       13 - 20                    Maybe
# ...

# %%
list(df.columns)
# Out:
# ['Timestamp',
#  'Username',
#  'Name',
#  'Stream',
#  'academic time',
#  'timetables and deadlines',
#  'task dedication',
#  'task without deadlines',
#  'physical activity',
#  'favorite sport',
#  'sport participation',
#  'family time',
#  'poor sleep',
#  'fitness',
#  'acheivements',
#  'empty feeling',
#  'loss of concentration',
#  'eating habits',
#  'distressed',
#  'losing interest in life',
#  'irritatable',
#  'free time',
#  'encouragement',
#  'motivation',
#  'academic experience',
#  'social media',
#  'socail media on academics',
#  'performance',
#  'satisfication',
#  'A valid opinion about your academic performance considering the context of questions asked above?']

# %%
df.drop(['Timestamp'], axis=1,inplace=True)

# %%
df
# Out:
#                          Username               Name    Stream academic time  \
# 0              erchitra@gmail.com   Sibhinandhan.E.R   Science       13 - 20
# 1           rsujithgopi@gmail.com      R.Sujith Gopi   Science       13 - 20
# 2              paavi795@gmail.com           Pavithra  Commerce        5 - 12
# 3            pranovshan@gmail.com   U Pranov Shanker   Science       13 - 20
# 4          anjuvenu2005@gmail.com            Anjana    Science        5 - 12
# ..                            ...                ...       ...           ...
# 214     priyasomraj3681@gmail.com  N.Harshinie Kumar   Science        5 - 12
# 215        banudhinahar@gmail.com            Laksman   Science       20 - 30
# 216   anirudh.sathish01@gmail.com          Anirudh.S  Commerce            <5
# 217  dhakshatha.rajan05@gmail.com        Dhakshatha    Science       20 - 30
# 218  sanjaivanchinathan@gmail.com           SANJAI.V   Science        5 - 12
#
# ...

# %%
#one hot encoding
